# %%
import importlib, sys
for pkg in ("hnswlib","faiss","faiss_cpu","nmslib"):
    try:
        m = importlib.import_module(pkg)
        print(pkg, "INSTALLED, version:", getattr(m, "__version__", "(unknown)"))
    except Exception as e:
        print(pkg, "NOT installed")
# Out:
# hnswlib NOT installed
# faiss NOT installed
# faiss_cpu NOT installed
# nmslib NOT installed

# %%
import hnswlib
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import hnswlib
#
# ModuleNotFoundError: No module named 'hnswlib'
