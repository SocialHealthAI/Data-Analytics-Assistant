# %%
# !ls ../agents
# Out:
#  Chinook.db			     'mcp_tool Get Post.py'
#  Finished			     'mcp_tool fastmcp.py'
#  __init__.py			      mcp_tool.py
#  __pycache__			      mean_statistical_tool.py
#  agents.py			      northwind.sql
#  base_statistical_tool.py	      schema_retriever_tool.py
#  chart_tool.py			     'search_tool using lnagchain-tavily.py'
#  chat_chart_react.py		      search_tool.py
#  chat_chart_react_v2.py		      sentence_transformer.py
#  chat_chart_react_v3.py		      sql_tool.py
#  feature_group_icons.json	      sql_tool_music
#  mapdata_tool.py		      sql_tool_music.py
# 'mcp_tool - mcp client.py'	      sql_tool_northwind.py
# 'mcp_tool - string parm version.py'   sql_tool_sdoh.py
