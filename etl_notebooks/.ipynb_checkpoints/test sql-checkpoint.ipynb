# %%
from sqlalchemy import create_engine, text
import pandas as pd

DB_URI = os.environ.get("DB_URI")
if not DB_URI:
    raise EnvironmentError(
        "DB_URI is not set."
    )

engine = create_engine(DB_URI)

# %%
sql = f"""
SELECT survey_year,
       AVG(ccbp_cs_rate) AS average_ccbp_cs_rate
FROM sdoh_surveys
WHERE survey_year BETWEEN 2017 AND 2020
GROUP BY survey_year
ORDER BY survey_year;
"""

with engine.connect() as conn:
    result = conn.execute(text(sql))
    # Convert to DataFrame preserving column names
    df = pd.DataFrame(result.mappings().all())

if df.empty:
    print("No rows returned for the given year range.")
else:
    # pretty-print the table
    print(df.to_string(index=False))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 from sqlalchemy import create_engine, text
#       2 import pandas as pd
# ----> 4 engine = create_engine(DB_URI)
#       5 TABLE_NAME = "sdoh_surveys"   # keep the same variable you used earlier
#       7 sql = f"""
#       8 SELECT survey_year,
#       9        AVG(ccbp_cs_rate) AS average_ccbp_cs_rate
#    (...)     13 ORDER BY survey_year;
#      14 """
#
# NameError: name 'DB_URI' is not defined
